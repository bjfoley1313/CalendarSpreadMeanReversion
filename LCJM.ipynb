# %%
import numpy as np
import pandas as pd
import Quandl
import statsmodels.tsa.stattools as ts
from datetime import datetime
from pandas import DataFrame
# %matplotlib inline
import matplotlib.pyplot as plt
import random

# %%
JM84 = Quandl.get("CME/LCJ1984.6", trim_start="1983-07-01", trim_end="1984-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1984.6", trim_start="1983-07-01", 
                    trim_end="1984-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM85 = Quandl.get("CME/LCJ1985.6", trim_start="1984-07-01", trim_end="1985-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1985.6", trim_start="1984-07-01", 
                    trim_end="1985-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM86 = Quandl.get("CME/LCJ1986.6", trim_start="1985-07-01", trim_end="1986-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1986.6", trim_start="1985-07-01", 
                    trim_end="1986-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM87 = Quandl.get("CME/LCJ1987.6", trim_start="1986-07-01", trim_end="1987-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1987.6", trim_start="1986-07-01", 
                    trim_end="1987-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM88 = Quandl.get("CME/LCJ1988.6", trim_start="1987-07-01", trim_end="1988-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1988.6", trim_start="1987-07-01", 
                    trim_end="1988-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM89 = Quandl.get("CME/LCJ1989.6", trim_start="1988-07-01", trim_end="1989-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1989.6", trim_start="1988-07-01", 
                    trim_end="1989-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM90 = Quandl.get("CME/LCJ1990.6", trim_start="1989-07-01", trim_end="1990-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1990.6", trim_start="1989-07-01", 
                    trim_end="1990-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM91 = Quandl.get("CME/LCJ1991.6", trim_start="1990-07-01", trim_end="1991-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1991.6", trim_start="1990-07-01", 
                    trim_end="1991-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM92 = Quandl.get("CME/LCJ1992.6", trim_start="1991-07-01", trim_end="1992-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1992.6", trim_start="1991-07-01", 
                    trim_end="1992-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM93 = Quandl.get("CME/LCJ1993.6", trim_start="1992-07-01", trim_end="1993-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1993.6", trim_start="1992-07-01", 
                    trim_end="1993-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM94 = Quandl.get("CME/LCJ1994.6", trim_start="1993-07-01", trim_end="1994-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1994.6", trim_start="1993-07-01", 
                    trim_end="1994-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM95 = Quandl.get("CME/LCJ1995.6", trim_start="1994-07-01", trim_end="1995-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1995.6", trim_start="1994-07-01", 
                    trim_end="1995-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM96 = Quandl.get("CME/LCJ1996.6", trim_start="1995-07-01", trim_end="1996-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1996.6", trim_start="1995-07-01", 
                    trim_end="1996-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM97 = Quandl.get("CME/LCJ1997.6", trim_start="1996-07-01", trim_end="1997-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1997.6", trim_start="1996-07-01", 
                    trim_end="1997-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM98 = Quandl.get("CME/LCJ1998.6", trim_start="1997-07-01", trim_end="1998-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1998.6", trim_start="1997-07-01", 
                    trim_end="1998-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM99 = Quandl.get("CME/LCJ1999.6", trim_start="1998-07-01", trim_end="1999-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM1999.6", trim_start="1998-07-01", 
                    trim_end="1999-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM00 = Quandl.get("CME/LCJ2000.6", trim_start="1999-07-01", trim_end="2000-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2000.6", trim_start="1999-07-01", 
                    trim_end="2000-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM01 = Quandl.get("CME/LCJ2001.6", trim_start="2000-07-01", trim_end="2001-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2001.6", trim_start="2000-07-01", 
                    trim_end="2001-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM02 = Quandl.get("CME/LCJ2002.6", trim_start="2001-07-01", trim_end="2002-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2002.6", trim_start="2001-07-01", 
                    trim_end="2002-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM03 = Quandl.get("CME/LCJ2003.6", trim_start="2002-07-01", trim_end="2003-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2003.6", trim_start="2002-07-01", 
                    trim_end="2003-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM04 = Quandl.get("CME/LCJ2004.6", trim_start="2003-07-01", trim_end="2004-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2004.6", trim_start="2003-07-01", 
                    trim_end="2004-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM05 = Quandl.get("CME/LCJ2005.6", trim_start="2004-07-01", trim_end="2005-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2005.6", trim_start="2004-07-01", 
                    trim_end="2005-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM06 = Quandl.get("CME/LCJ2006.6", trim_start="2005-07-01", trim_end="2006-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2006.6", trim_start="2005-07-01", 
                    trim_end="2006-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM07 = Quandl.get("CME/LCJ2007.6", trim_start="2006-07-01", trim_end="2007-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2007.6", trim_start="2006-07-01", 
                    trim_end="2007-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM08 = Quandl.get("CME/LCJ2008.6", trim_start="2007-07-01", trim_end="2008-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2008.6", trim_start="2007-07-01", 
                    trim_end="2008-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM09 = Quandl.get("CME/LCJ2009.6", trim_start="2008-07-01", trim_end="2009-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2009.6", trim_start="2008-07-01", 
                    trim_end="2009-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM10 = Quandl.get("CME/LCJ2010.6", trim_start="2009-07-01", trim_end="2010-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2010.6", trim_start="2009-07-01", 
                    trim_end="2010-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM11 = Quandl.get("CME/LCJ2011.6", trim_start="2010-07-01", trim_end="2011-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2011.6", trim_start="2010-07-01", 
                    trim_end="2011-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM12 = Quandl.get("CME/LCJ2012.6", trim_start="2011-07-01", trim_end="2012-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2012.6", trim_start="2011-07-01", 
                    trim_end="2012-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM13 = Quandl.get("CME/LCJ2013.6", trim_start="2012-07-01", trim_end="2013-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2013.6", trim_start="2012-07-01", 
                    trim_end="2013-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM14 = Quandl.get("CME/LCJ2014.6", trim_start="2013-07-01", trim_end="2014-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2014.6", trim_start="2013-07-01", 
                    trim_end="2014-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")
JM15 = Quandl.get("CME/LCJ2015.6", trim_start="2014-07-01", trim_end="2015-04-01",
                   authtoken="V59QDSuBq4zt1ofAQxRv") - Quandl.get("CME/LCM2015.6", trim_start="2014-07-01", 
                    trim_end="2015-04-01",authtoken="V59QDSuBq4zt1ofAQxRv")

# %%
frames = [JM85,JM86,JM87,JM88,JM89,JM90,JM91,JM92,JM93,JM94,JM95,JM96,JM97,JM98,JM99,JM00,
          JM01,JM02,JM03,JM04,JM05,JM06,JM07,JM08,JM09,JM10,JM11,JM12,JM13,JM14,JM15]
allofem = pd.concat(frames)

# %%
allofem2 = allofem['Settle'].dropna()

# %%
ts.adfuller(allofem2,1)
# Out:
# (-4.8028800273515921,
#  5.3700188261319502e-05,
#  1,
#  5863,
#  {'1%': -3.4314658392205684,
#   '10%': -2.5670324729841822,
#   '5%': -2.8620330962511855},
#  1784.7503819684553)

# %%
allofem.plot.line()
allofem.plot.hist(bins=25)
JM13.plot.line()
JM14.plot.line()
JM15.plot.line()

# %%
pd.set_option('display.max_rows', 500)
allofem.describe ([.01,.02,.03,.04,.05,.06,.07,.08,.09,.1,.11,.12,.13,.14,.15,.16,.17,.18,.19,.2,
                   .21,.22,.23,.24,.25,.26,.27,.28,.29,.3,.31,.32,.33,.34,.35,.36,.37,.38,.39,.4,
                   .41,.42,.43,.44,.45,.46,.47,.48,.49,.5,.51,.52,.53,.54,.55,.56,.57,.58,.59,.6,
                   .61,.62,.63,.64,.65,.66,.67,.68,.69,.7,.71,.72,.73,.74,.75,.76,.77,.78,.79,.8,
                   .81,.82,.83,.84,.85,.86,.87,.88,.89,.9,.91,.92,.93,.94,.95,.96,.97,.98,.99])
# Out:
#             Settle
# count  5865.000000
# mean      3.071451
# std       2.183923
# min      -3.330000
# 1%       -1.730800
# 2%       -1.114400
# 3%       -1.000000
# 4%       -0.830000
# 5%       -0.530000
# 6%       -0.350000
# 7.0%     -0.200000
# 8%       -0.050000
# 9%        0.050000
# 10%       0.138000
# 11%       0.270000
# 12%       0.400000
# 13%       0.500000
# 14.0%     0.620000
# 15%       0.750000
# 16%       0.900000
# 17%       1.020000
# 18%       1.130000
# 19%       1.275800
# 20%       1.400000
# 21%       1.500000
# 22%       1.575000
# 23%       1.650000
# 24%       1.750000
# 25%       1.820000
# 26%       1.900000
# 27%       1.950000
# 28.0%     2.020000
# 29.0%     2.050000
# 30%       2.100000
# 31%       2.150000
# 32%       2.172400
# 33%       2.225600
# 34%       2.275000
# 35%       2.320000
# 36%       2.370000
# 37%       2.420000
# 38%       2.470000
# 39%       2.500000
# 40%       2.550000
# 41%       2.600000
# 42%       2.650000
# ...
